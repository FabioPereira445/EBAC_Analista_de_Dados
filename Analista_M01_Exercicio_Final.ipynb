# %% [markdown]
# Exercicio 1 Parte 1 E Parte 2

# %%
 #PARTE 1
 print('Olá mundo ,olá Brasil! eu sou o Fabio um dos maiores analistas de Dados do brasil e extremamente requisitado pelas multinacionais, formado pela EBAC')
# Out:
# Olá mundo ,olá Brasil! eu sou o Fabio um dos maiores analistas de Dados do brasil e extremamente requisitado pelas multinacionais, formado pela EBAC

# %% [markdown]
# # ![tigre.webp](data:image/webp;base64,...)

# %% [markdown]
# #Exercício 2 Parte 1 , Parte 2 E Parte 3

# %%
#EXERCICIO 2 PARTE 1 OJETIVO: CALCULAR O VALOR TOTAL DE VENDAS REFERENTE A CÉLULA (A)EM 19/01


quantidade_vendas = 3
ticket_medio = 320.52

valor_total_vendas = quantidade_vendas * ticket_medio

print(f"O valor total de vendas referente a A em 19/01 é: R${valor_total_vendas:.2f}")
# Out:
# O valor total de vendas referente a A em 19/01 é: R$961.56

# %%
#PARTE 2 OJETIVO: CALCULAR O  TOTAL DE VENDAS REFERENTE A CÉLULA (B)EM 20/01


valor_total_vendas = 834.47
ticket_medio = 119.21

quantidade_total_vendas = valor_total_vendas / ticket_medio

print(f"A quantidade total de vendas referente a B em 20/01 é: {int(quantidade_total_vendas)}")
# Out:
# A quantidade total de vendas referente a B em 20/01 é: 7

# %%
#PARTE 3 OJETIVO: CALCULAR O  ticket médio REFERENTE A CÉLULA (C)EM 23/01


valor_total_vendas = 15378.12
quantidade_total_vendas = 5

ticket_medio = valor_total_vendas / quantidade_total_vendas

print(f"O ticket médio em 23/01 referente a C é: R${ticket_medio:.2f}")
# Out:
# O ticket médio em 23/01 referente a C é: R$3075.62

# %% [markdown]
# #Exercício 3 :String Parte 1 E Parte 2

# %%
#EXERCICIO 3 :STRING PARTE 1

#Método 1: replace()
# Este método substitui todas as ocorrências de uma substring por outra substring

cancao = 'Roda mundo, roda gigante, roda moinho, roda pião.'
cancao_replace = cancao.replace("roda", "gira")
print(cancao_replace)
# Out:
# Roda mundo, gira gigante, gira moinho, gira pião.

# %%
# Método 2: split()
# Este método divide a string em uma lista de substrings com base em um separador
cancao_split = cancao.split(", ")
print(cancao_split)
# Out:
# ['Roda mundo', 'roda gigante', 'roda moinho', 'roda pião.']

# %%
# Método 3: upper()
# Este método converte todos os caracteres da string para maiúsculas
cancao_upper = cancao.upper()
print(cancao_upper)
# Out:
# RODA MUNDO, RODA GIGANTE, RODA MOINHO, RODA PIÃO.

# %%
#PARTE 2 OBJETIVO:Extraia da string abaixo o valor da taxa selic na variável selic e o valor do ano na variável ano . Imprima os valores na tela.

noticia = 'Selic vai a 2,75% e supera expectativas; é a primeira alta em 6 anos.'

# Extraindo o valor da taxa Selic
selic_str = noticia.split()[3].replace(',', '.').replace('%', '')
selic = float(selic_str)

# Extraindo o ano da notícia
ano = int(noticia.split()[-2])

# Imprimindo os valores na tela
print(f"Valor da Selic: {selic:.2f}")
print(f"Ano: {ano}")
# Out:
# Valor da Selic: 2.75
# Ano: 6

# %% [markdown]
# # 4º Exercício: Booleanos

# %%
#Neste código, a variável a é inicializada com o valor False e a variável b é inicializada com o valor True. Em seguida,
# usamos o operador not para negar o valor de a e o operador and para verificar se ambos not a e b são verdadeiros. Como not a é verdadeiro
#(ou seja, a é falso) e b é verdadeiro, o resultado da expressão é verdadeiro (ou seja, x é verdadeiro).
# Por fim, usamos a função print() para imprimir o valor de x na tela.

a = False
b = True
x = not a and b
print(x)  # Saída: verdadeiro
# Out:
# True
